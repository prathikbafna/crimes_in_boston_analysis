# %%
import pandas as pd

# %%
pb =pd.read_csv("days.csv")

# %%
pb
# Out:
#          day      value
# 0     Monday  13.290461
# 1    Tuesday  14.147910
# 2  Wednesday  11.682744
# 3   Thursday  17.470525
# 4     Friday  12.647374
# 5   Saturday  15.434084
# 6     Sunday  15.326902

# %%
min = pb['value'].min()
max = pb['value'].max() 
range=max-min

# %%
for i in range(0,7):
    pb['Value'][i]=(pb['Value'][i]-min)/range
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ec53c2b67e4c> in <module>
# ----> 1 for i in range(0,7):
#       2     pb['Value'][i]=(pb['Value'][i]-min)/range
#
# TypeError: 'numpy.float64' object is not callable

# %%
pb['day']=pd.to_numeric(pb['day'],errors='corence')

# %%
pb
# Out:
#    day      value
# 0  NaN  13.290461
# 1  NaN  14.147910
# 2  NaN  11.682744
# 3  NaN  17.470525
# 4  NaN  12.647374
# 5  NaN  15.434084
# 6  NaN  15.326902

# %%
from sklearn import preprocessing

x = pb.value #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
pb = pd.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-65e5ec3732f2> in <module>
#       3 x = pb.value #returns a numpy array
#       4 min_max_scaler = preprocessing.MinMaxScaler()
# ----> 5 x_scaled = min_max_scaler.fit_transform(x)
#       6 pb = pd.DataFrame(x_scaled)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     323         # Reset internal state before fitting
#     324         self._reset()
# --> 325         return self.partial_fit(X, y)
#     326
# ...

# %%
df=pd.read_csv("auto_theft_complete_nafilled.csv")

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP DISTRICT  REPORTING_AREA  \
# 0      I182070933           724         Auto Theft       B2           330.0
# 1      I182070844           724         Auto Theft       D4           154.0
# 2      I182070766           706         Auto Theft       D4           623.0
# 3      I182070610           724         Auto Theft       B3           449.0
# 4      I182070563           706         Auto Theft       D4           135.0
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR            STREET
# 0  2018-09-03 21:25:00  2018      9      Monday    21       NORMANDY ST
# 1  2018-09-03 15:01:00  2018      9      Monday    15        TREMONT ST
# 2  2018-09-02 20:00:00  2018      9      Sunday    20  COMMONWEALTH AVE
# 3  2018-09-02 18:20:00  2018      9      Sunday    18        SPENCER ST
# 4  2018-09-01 23:00:00  2018      9    Saturday    23         BEACON ST

# %%
pb=df
from sklearn import preprocessing
pb=preprocessing.LabelEncoder()
pb.fit(df['DAY_OF_WEEK'].unique())
df['DAY_OF_WEEK']=pb.transform(df['DAY_OF_WEEK'])

# %%
df['DAY_OF_WEEK'].describe()
# Out:
# count    933.000000
# mean       3.008574
# std        1.902656
# min        0.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max        6.000000
# Name: DAY_OF_WEEK, dtype: float64

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP DISTRICT  REPORTING_AREA  \
# 0      I182070933           724         Auto Theft       B2           330.0
# 1      I182070844           724         Auto Theft       D4           154.0
# 2      I182070766           706         Auto Theft       D4           623.0
# 3      I182070610           724         Auto Theft       B3           449.0
# 4      I182070563           706         Auto Theft       D4           135.0
#
#       OCCURRED_ON_DATE  YEAR  MONTH  DAY_OF_WEEK  HOUR            STREET
# 0  2018-09-03 21:25:00  2018      9            1    21       NORMANDY ST
# 1  2018-09-03 15:01:00  2018      9            1    15        TREMONT ST
# 2  2018-09-02 20:00:00  2018      9            3    20  COMMONWEALTH AVE
# 3  2018-09-02 18:20:00  2018      9            3    18        SPENCER ST
# 4  2018-09-01 23:00:00  2018      9            2    23         BEACON ST

# %%
df.to_csv("normal.csv",columns=['OFFENSE_CODE','REPORTING_AREA','DAY_OF_WEEK'],index=False)

# %%
n=pd.read_csv("normal.csv")

# %%
n.head(8)
# Out:
#    OFFENSE_CODE  REPORTING_AREA  DAY_OF_WEEK
# 0           724           330.0            1
# 1           724           154.0            1
# 2           706           623.0            3
# 3           724           449.0            3
# 4           706           135.0            2
# 5           706           135.0            3
# 6           724           358.0            2
# 7           724           326.0            2

# %%
n=(n-n.min())/(n.max()-n.min())

# %%
n.head(8)
# Out:
#    OFFENSE_CODE  REPORTING_AREA  DAY_OF_WEEK
# 0      0.857143        0.339362     0.166667
# 1      0.857143        0.152128     0.166667
# 2      0.000000        0.651064     0.500000
# 3      0.857143        0.465957     0.500000
# 4      0.000000        0.131915     0.333333
# 5      0.000000        0.131915     0.500000
# 6      0.857143        0.369149     0.333333
# 7      0.857143        0.335106     0.333333

# %%
n['OFFENSE_CODE'].plot.hist()
n['OFFENSE_CODE'].describe()
# Out:
# count    933.000000
# mean       0.730822
# std        0.325196
# min        0.000000
# 25%        0.857143
# 50%        0.857143
# 75%        0.857143
# max        1.000000
# Name: OFFENSE_CODE, dtype: float64

# %%
n['REPORTING_AREA'].plot.hist()
n['REPORTING_AREA'].describe()
# Out:
# count    933.000000
# mean       0.369026
# std        0.227940
# min        0.000000
# 25%        0.186170
# 50%        0.329787
# 75%        0.486170
# max        1.000000
# Name: REPORTING_AREA, dtype: float64

# %%
n['DAY_OF_WEEK'].plot.hist()
n['DAY_OF_WEEK'].describe()
# Out:
# count    933.000000
# mean       0.501429
# std        0.317109
# min        0.000000
# 25%        0.166667
# 50%        0.500000
# 75%        0.833333
# max        1.000000
# Name: DAY_OF_WEEK, dtype: float64

# %%
n.head()
# Out:
#    OFFENSE_CODE  REPORTING_AREA  DAY_OF_WEEK
# 0      0.857143        0.339362     0.166667
# 1      0.857143        0.152128     0.166667
# 2      0.000000        0.651064     0.500000
# 3      0.857143        0.465957     0.500000
# 4      0.000000        0.131915     0.333333

# %%
n=(n-n.mean())/n.std()

# %%
n.describe()
# Out:
#        OFFENSE_CODE  REPORTING_AREA   DAY_OF_WEEK
# count  9.330000e+02    9.330000e+02  9.330000e+02
# mean   7.657326e-16   -3.012283e-15  1.968653e-15
# std    1.000000e+00    1.000000e+00  1.000000e+00
# min   -2.247329e+00   -1.618958e+00 -1.581250e+00
# 25%    3.884447e-01   -8.022081e-01 -1.055669e+00
# 50%    3.884447e-01   -1.721440e-01 -4.506591e-03
# 75%    3.884447e-01    5.139258e-01  1.046656e+00
# max    8.277404e-01    2.768155e+00  1.572237e+00

# %%
s=pd.read_csv("normal.csv")

# %%
s=(s-s.mean())/s.std()

# %%
s.describe()
# Out:
#        OFFENSE_CODE  REPORTING_AREA   DAY_OF_WEEK
# count  9.330000e+02    9.330000e+02  9.330000e+02
# mean  -8.830140e-15    5.082572e-17 -8.210653e-17
# std    1.000000e+00    1.000000e+00  1.000000e+00
# min   -2.247329e+00   -1.618958e+00 -1.581250e+00
# 25%    3.884447e-01   -8.022081e-01 -1.055669e+00
# 50%    3.884447e-01   -1.721440e-01 -4.506591e-03
# 75%    3.884447e-01    5.139258e-01  1.046656e+00
# max    8.277404e-01    2.768155e+00  1.572237e+00

# %%
s['REPORTING_AREA'].plot.hist()

# %%
h=pd.read_csv("crimes_in_year_2018.csv")

# %%
h.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP DISTRICT REPORTING_AREA  \
# 0      I182070945           619               Larceny      D14            808
# 1      I182070943          1402             Vandalism      C11            347
# 2      I182070941          3410                 Towed       D4            151
# 3      I182070940          3114  Investigate Property       D4            272
# 4      I182070938          3114  Investigate Property       B3            421
#
#       OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR       STREET
# 0  2018-09-02 13:00:00  2018      9      Sunday    13   LINCOLN ST
# 1  2018-08-21 00:00:00  2018      8     Tuesday     0     HECLA ST
# 2  2018-09-03 19:27:00  2018      9      Monday    19  CAZENOVE ST
# 3  2018-09-03 21:16:00  2018      9      Monday    21   NEWCOMB ST
# 4  2018-09-03 21:05:00  2018      9      Monday    21     DELHI ST

# %%
h['REPORTING_AREA']=pd.to_numeric(h['REPORTING_AREA'],errors='corence')

# %%
h.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP DISTRICT  \
# 0      I182070945           619               Larceny      D14
# 1      I182070943          1402             Vandalism      C11
# 2      I182070941          3410                 Towed       D4
# 3      I182070940          3114  Investigate Property       D4
# 4      I182070938          3114  Investigate Property       B3
#
#    REPORTING_AREA     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0           808.0  2018-09-02 13:00:00  2018      9      Sunday    13
# 1           347.0  2018-08-21 00:00:00  2018      8     Tuesday     0
# 2           151.0  2018-09-03 19:27:00  2018      9      Monday    19
# 3           272.0  2018-09-03 21:16:00  2018      9      Monday    21
# 4           421.0  2018-09-03 21:05:00  2018      9      Monday    21
#
#         STREET
# 0   LINCOLN ST
# 1     HECLA ST
# 2  CAZENOVE ST
# 3   NEWCOMB ST
# 4     DELHI ST

# %%
mu=h['REPORTING_AREA'].mean()

# %%
sample=h[0:100]

# %%
X_BAR=sample['REPORTING_AREA'].mean()
sigma=h['REPORTING_AREA'].std()
n=100

# %%
Z=(X_BAR-mu)/(sigma/10)

# %%
Z
# Out:
# 0.18331853387117536

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv('crime.csv', encoding='latin-1')

# %%
G1=data[data['MONTH'].isin(data['MONTH'].value_counts()[1:11].index)]
pd.crosstab(G1.YEAR,G1.DISTRICT).plot(color=sns.color_palette('dark',6))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %%
sns.distplot(data['HOUR'],bins=24,hist=True,rug=True)

# %%
def convert(hour):
    if hour>6 and hour<19:
        return 'Day'
    else:
        return 'Night'
data['DAY_OR_NIGHT'] = data['HOUR'].apply(convert)

# %%
def convert(hour):
    day_c=0
    night_c=0
    if hour>6 and hour<19:
        day_c=day_c+1
    else:
        night_c=night_c+1
x=data['HOUR'].apply(convert)

# %%
sns.countplot(x=data['DAY_OR_NIGHT'],palette='viridis')

# %%
data
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# 0           I182070945           619                           Larceny
# 1           I182070943          1402                         Vandalism
# 2           I182070941          3410                             Towed
# 3           I182070940          3114              Investigate Property
# 4           I182070938          3114              Investigate Property
# 5           I182070936          3820   Motor Vehicle Accident Response
# 6           I182070933           724                        Auto Theft
# 7           I182070932          3301                   Verbal Disputes
# 8           I182070931           301                           Robbery
# 9           I182070929          3301                   Verbal Disputes
# 10          I182070928          3301                   Verbal Disputes
# 11          I182070927          3114              Investigate Property
# ...

# %%
data['HOUR'].mean()
# Out:
# 13.118204924891796

# %%
n=30000
sample=data[0:n]
X_BAR=sample['HOUR'].mean()
sigma=data['HOUR'].std()

root_n = n**0.5

# %%
Z=(X_BAR-mu)/(sigma/root_n)

# %%
X_BAR
# Out:
# 13.130233333333333

# %%
sigma
# Out:
# 6.2942052659402385

# %%
Z
# Out:
# -10176.478151396963

# %%
from scipy.stats import ttest_ind
import numpy as np
import pandas as pd
ttest,pval = ttest_ind(week1,week2)
print("p-value",pval)
if pval <0.05:
  print("we reject null hypothesis")
else:
  print("we accept null hypothesis")

# %%
df=pd.read_csv("crimes_in_year_2018.csv")

# %%
df1=pd.read_csv("crimes_in_year_2017.csv")

# %%
df
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE                OFFENSE_CODE_GROUP  \
# 0          I182070945           619                           Larceny
# 1          I182070943          1402                         Vandalism
# 2          I182070941          3410                             Towed
# 3          I182070940          3114              Investigate Property
# 4          I182070938          3114              Investigate Property
# 5          I182070936          3820   Motor Vehicle Accident Response
# 6          I182070933           724                        Auto Theft
# 7          I182070932          3301                   Verbal Disputes
# 8          I182070931           301                           Robbery
# 9          I182070929          3301                   Verbal Disputes
# 10         I182070928          3301                   Verbal Disputes
# 11         I182070927          3114              Investigate Property
# ...

# %%
df_17=pd.read_csv("crimes_in_year_2017.csv")

# %%
df_18=pd.read_csv("crimes_in_year_2018.csv")

# %%
df_17.count()
# Out:
# INCIDENT_NUMBER       100886
# OFFENSE_CODE          100886
# OFFENSE_CODE_GROUP    100886
# DISTRICT              100886
# REPORTING_AREA        100886
# OCCURRED_ON_DATE      100886
# YEAR                  100886
# MONTH                 100886
# DAY_OF_WEEK           100886
# HOUR                  100886
# STREET                100886
# dtype: int64

# %%
x=df_17.OFFENSE_CODE_GROUP.value_counts()

# %%
total_17=sum(x)

# %%
mean_17=total_17/66

# %%
mean_17
# Out:
# 1528.5757575757575

# %%
y=df_18.OFFENSE_CODE_GROUP.value_counts()

# %% [markdown]
# total_18=sum(y)

# %%
total_18=sum(y)

# %%
mean_18=total_18/66

# %%
mean_18
# Out:
# 995.2272727272727

# %%
a=pd.read_csv("nafilled.csv")
from sklearn.utils import shuffle
a = shuffle(a)
a.to_csv("shuffled.csv",index=False)

# %%
x=pd.read_csv("shuffled.csv", skiprows=10000, nrows=20000)

# %%
y_17=x[x['2015']==2017]

# %%
y_18=x[x['2015']==2018]

# %%
total_17 = y_17.count

# %%
total_18 = y_18.count

# %%
total_17=6339

# %%
total_18=4150

# %%
import pandas as pd

# %%
data = pd.read_csv('crime.csv', encoding='latin-1')

# %%
data.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0      I182070945           619               Larceny    LARCENY ALL OTHERS
# 1      I182070943          1402             Vandalism             VANDALISM
# 2      I182070941          3410                 Towed   TOWED MOTOR VEHICLE
# 3      I182070940          3114  Investigate Property  INVESTIGATE PROPERTY
# 4      I182070938          3114  Investigate Property  INVESTIGATE PROPERTY
#
#   DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0      D14            808      NaN  2018-09-02 13:00:00  2018      9
# 1      C11            347      NaN  2018-08-21 00:00:00  2018      8
# 2       D4            151      NaN  2018-09-03 19:27:00  2018      9
# 3       D4            272      NaN  2018-09-03 21:16:00  2018      9
# 4       B3            421      NaN  2018-09-03 21:05:00  2018      9
#
#   DAY_OF_WEEK  HOUR    UCR_PART       STREET        Lat       Long  \
# ...

# %%
P=data[data['HOUR']>=6]

# %%
p=data[data['HOUR']<=18]

# %%
count_row = data.shape[0]

# %%
count_success = p.shape[0]

# %%
propotion=count_success/count_row

# %%
propotion
# Out:
# 0.7772578688889377

# %%
#as we have the total population we are calculating the propotion and making the hypothesis
#we will conclude by the hypothesis test whether  our assumption is right or wrong 
#H0: p = 0.777
#H1: p ≠ 0.777
#np=(count_row)(0.777) and n(1−p)=(count_row)(1−0.77) are above 10 so we can use normal model to find P value
#let us take a sample of size 10,000 and conduct the  test
x=pd.read_csv("shuffled.csv",nrows=20000)
#P_cap=x[x['12']>=6]  #here 12 has become the column name
#P_cap=x[x['12']<=18]
#n=10000
#success=P_cap.shape[0]
#p_bar=success/n

# %%
P_cap=x[x['HOUR']>=6]  #here 12 has become the column name
P_cap=x[x['HOUR']<=18]
n=20000
success=P_cap.shape[0]
p_bar=success/n

# %%
p_bar
# Out:
# 0.77845

# %%
propotion
# Out:
# 0.7772578688889377

# %%
Z=(p_bar-propotion)/(((propotion*(1-propotion))/n)**0.5)

# %%
Z
# Out:
# 0.4051867832839335

# %%
import numpy as np
import scipy.special as scsp
def z2p(Z):
    """From z-score return p-value."""
    return 0.5 * (1 + scsp.erf(Z / np.sqrt(2)))

# %%
p_val=z2p(Z)

# %%
p_val
# Out:
# 0.6573298903426008

# %%
data = pd.read_csv('nafilled.csv')

# %%
x=data.DISTRICT.value_counts()

# %%
district=['B2',
'C11',    
'D4' ,    
'A1' ,    
'B3',     
'C6',     
'D14',    
'E13',    
'E18',    
'A7',     
'E5',     
'A15' ]

# %%
import numpy as np
import matplotlib.pyplot as pls
index=np.arange(len(x))
pls.bar(index,x)
pls.xlabel('districts', fontsize=10)
pls.ylabel('No of crimes', fontsize=10) 
pls.xticks(index, district, fontsize=10, rotation=30)
pls.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as pls

# %%
df=pd.read_csv("shuffled.csv")

# %%
sns.pairplot(df)

# %%
data=pd.read_csv("shuffled.csv")

# %%
pls.figure(figsize=(16,6))
c=data.corr(method='pearson')
c

# %%
ax=sns.heatmap(c,xticklabels=c.columns,yticklabels=c.columns,cmap='RdBu_r',annot=True,linewidth=0.2)
bottom,top=ax.get_ylim()
ax.set_ylim(bottom+0.5,top-0.5)

# %%
c=data.corr(method='pearson')

# %%
c
# Out:
#                 OFFENSE_CODE  REPORTING_AREA      YEAR     MONTH      HOUR
# OFFENSE_CODE        1.000000        0.048522  0.045103 -0.014322 -0.017036
# REPORTING_AREA      0.048522        1.000000  0.004354 -0.004989  0.019942
# YEAR                0.045103        0.004354  1.000000 -0.383351  0.001945
# MONTH              -0.014322       -0.004989 -0.383351  1.000000  0.002051
# HOUR               -0.017036        0.019942  0.001945  0.002051  1.000000

# %%
selected=pd.read_csv("shuffled.csv")

# %%
ax1 = data.plot.scatter(x='REPORTING_AREA',
                      y='OFFENSE_CODE',
                      c='DarkBlue')

# %%
data['REPORTING_AREA'].corr(data['OFFENSE_CODE'],method="pearson")
# Out:
# 0.04852228863628144

# %%
data=data[['REPORTING_AREA', 'OFFENSE_CODE'] nrows=1000]
# Out:
#   File "<ipython-input-17-828d3b9b3875>", line 1
#     data=data[['REPORTING_AREA', 'OFFENSE_CODE'] nrows=1000]
#                                                      ^
# SyntaxError: invalid syntax

# %%
data=pd.read_csv("shuffled.csv",nrows=1000)
data=data[['REPORTING_AREA', 'OFFENSE_CODE']] 
ax1 = data.plot.scatter(x='REPORTING_AREA',
                      y='OFFENSE_CODE',
                      c='DarkBlue')

# %%
data.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE               OFFENSE_CODE_GROUP DISTRICT  \
# 0      I172083705          3115               Investigate Person      E13
# 1      I152091690          3410                            Towed      C11
# 2      I172016555          3802  Motor Vehicle Accident Response      D14
# 3      I162036201          3301                  Verbal Disputes       A7
# 4      I172005474           613                          Larceny       A7
#
#    REPORTING_AREA     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0           638.0  2017-10-07 13:59:00  2017     10    Saturday    13
# 1           249.0  2015-11-04 18:34:00  2015     11   Wednesday    18
# 2           793.0  2017-03-01 13:52:00  2017      3   Wednesday    13
# 3            17.0  2016-05-09 19:10:00  2016      5      Monday    19
# 4            26.0  2017-01-21 07:29:00  2017      1    Saturday     7
#
#              STREET
# 0       BOYLSTON ST
# 1         SAXTON ST
# 2  COMMONWEALTH AVE
# ...

# %%
data.boxplot(by='REPORTING_AREA',column=['REPORTING_AREA'], grid=False)

# %%
c
